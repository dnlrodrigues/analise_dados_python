# %% [markdown]
# <a href="https://colab.research.google.com/github/dnlrodrigues/analise_dados_python/blob/master/Copy_of_Copy_of_QuarentenasDados_Filme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aula - 1**

# %%
print("Daniela")
# Out:
# Daniela

# %%
nome_do_filme = "Totoro"

# %%
print(nome_do_filme)
# Out:
# Totoro

# %%
nome_do_filme
# Out:
# 'Totoro'

# %%
import pandas as pd

# %%
pd.read_csv("/home/dataset/movies.csv")
# Out:
#       movieId  ...                                       genres
# 0           1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1           2  ...                   Adventure|Children|Fantasy
# 2           3  ...                               Comedy|Romance
# 3           4  ...                         Comedy|Drama|Romance
# 4           5  ...                                       Comedy
# ...       ...  ...                                          ...
# 9737   193581  ...              Action|Animation|Comedy|Fantasy
# 9738   193583  ...                     Animation|Comedy|Fantasy
# 9739   193585  ...                                        Drama
# 9740   193587  ...                             Action|Animation
# 9741   193609  ...                                       Comedy
#
# [9742 rows x 3 columns]

# %%
filmes =  pd.read_csv("/home/dataset/movies.csv")
#pd.read_csv devolve um dataframe então o filmes é um dataframe
filmes.head()
#?filmes #mostrar a documentacao deve-se colocar um ? na frente da variável, opção do jupiter
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
avaliacoes = pd.read_csv("/home/dataset/ratings.csv")

# %%
avaliacoes.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
#para ver o formato sendo o primeiro parâmetro o número de linhas e o segundo o número de colunas
avaliacoes.shape
# Out:
# (100836, 4)

# %%
#somente o número de linhas
len(avaliacoes)
# Out:
# 100836

# %%
avaliacoes.columns = ["usuarioId", "filmeId", "nota", "momento"]
avaliacoes.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
avaliacoes.query("filmeId==1")
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
#dados como média, mediana, min, max, total de notas, desvio padrão entre outros da avaliações
avaliacoes.describe()
# Out:
#            usuarioId        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
#pegar um coluna, o seu resultado não será um dataframe e sim uma série
avaliacoes["nota"]
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
avaliacoes.query("filmeId==1").describe()
# Out:
#         usuarioId  filmeId        nota       momento
# count  215.000000    215.0  215.000000  2.150000e+02
# mean   306.530233      1.0    3.920930  1.129835e+09
# std    180.419754      0.0    0.834859  2.393163e+08
# min      1.000000      1.0    0.500000  8.293223e+08
# 25%    155.500000      1.0    3.500000  8.779224e+08
# 50%    290.000000      1.0    4.000000  1.106855e+09
# 75%    468.500000      1.0    4.500000  1.348523e+09
# max    610.000000      1.0    5.000000  1.535710e+09

# %%
#epgar a média do filme 1
avaliacoes.query("filmeId==1").mean()
# Out:
# usuarioId    3.065302e+02
# filmeId      1.000000e+00
# nota         3.920930e+00
# momento      1.129835e+09
# dtype: float64

# %%
#pegar a média da coluna nota do filme 1
avaliacoes.query("filmeId==1")["nota"].mean()
# Out:
# 3.9209302325581397

# %%
#agrupando colunas
avaliacoes.groupby("filmeId")

# %%
avaliacoes.groupby("filmeId").mean()
# Out:
#           usuarioId      nota       momento
# filmeId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
#agrupar colunas pela coluna filmeId e pegar a média da coluna nota
#padrão de variáveis no python é por _
notas_media_por_filme = avaliacoes.groupby("filmeId")["nota"].mean()
notas_media_por_filme
# Out:
# filmeId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
notas_media_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
#criar coluna no dataset filmes e colar notas no dataset sem fazer o joiner, juntando ambos mesmo que ambos tenham diferentes totais de linhas 
#avaliacoes["notas_media"] = notas_media_por_filme

#inserir coluna notas_media_por_filme("serie") no filme("dataset") fazendo um joiner com o id do filme no dataset com o id do filme na serie
#No método join o primeiro parâmetro pode ser um other que pode ser um dataframe ou uma série e o segundo é a coluna do join
filmes.columns = ["filmeId", "titulo", "generos"]
filmes_com_media = filmes.join(notas_media_por_filme, on="filmeId")
filmes_com_media
# Out:
#       filmeId  ...      nota
# 0           1  ...  3.920930
# 1           2  ...  3.431818
# 2           3  ...  3.259615
# 3           4  ...  2.357143
# 4           5  ...  3.071429
# ...       ...  ...       ...
# 9737   193581  ...  4.000000
# 9738   193583  ...  3.500000
# 9739   193585  ...  3.500000
# 9740   193587  ...  3.500000
# 9741   193609  ...  4.000000
#
# [9742 rows x 4 columns]

# %% [markdown]
# # DESAFIO 1
# Buscar os filmes que não tem nota

# %%
filmes_joiner_right = filmes.join(notas_media_por_filme, on="filmeId", how='left')
#filmes_joiner_right["nao_tem_nota"] = filmes_joiner_right["nota"].isnull()
#filmes_joiner_right.sort_values("nao_tem_nota", ascending=False).head(18)
filmes_joiner_null = pd.isnull(filmes_joiner_right["nota"])
filmes_joiner_right[filmes_joiner_null]
# Out:
#       filmeId  ... nota
# 816      1076  ...  NaN
# 2211     2939  ...  NaN
# 2499     3338  ...  NaN
# 2587     3456  ...  NaN
# 3118     4194  ...  NaN
# 4037     5721  ...  NaN
# 4506     6668  ...  NaN
# 4598     6849  ...  NaN
# 4704     7020  ...  NaN
# 5020     7792  ...  NaN
# 5293     8765  ...  NaN
# 5421    25855  ...  NaN
# 5452    26085  ...  NaN
# 5749    30892  ...  NaN
# 5824    32160  ...  NaN
# 5837    32371  ...  NaN
# 5957    34482  ...  NaN
# 7565    85565  ...  NaN
#
# [18 rows x 4 columns]

# %% [markdown]
# # DESAFIO 2
# Mudar o nome da coluna nota após o join

# %%
filmes_com_media = filmes_com_media.rename(columns={"nota":"notas"})
filmes_com_media.head()
# Out:
#    filmeId  ... notas
# 0        1  ...   4.0
# 1        2  ...   3.0
# 2        3  ...   3.0
# 3        4  ...   2.0
# 4        5  ...   3.0
#
# [5 rows x 4 columns]

# %%
#pode ser ordernado pelo index(sort_index) ou por alguma coluna(sort_values), por default a ordenação é asc
#no primeiro parâmetro da ordernação sort_value é a coluna que deseja ordernar e o segundo é o tipo de ordenação
#para ordernação desc o ascending deve ser False
filmes_com_media.sort_values("notas", ascending=False).head(15)
# Out:
#       filmeId  ... notas
# 7656    88448  ...   5.0
# 8107   100556  ...   5.0
# 9083   143031  ...   5.0
# 9094   143511  ...   5.0
# 9096   143559  ...   5.0
# 4251     6201  ...   5.0
# 8154   102217  ...   5.0
# 8148   102084  ...   5.0
# 4246     6192  ...   5.0
# 9122   145994  ...   5.0
# 8115   100906  ...   5.0
# 9129   146662  ...   5.0
# 8074    99636  ...   5.0
# 5785    31522  ...   5.0
# 9131   146684  ...   5.0
#
# [15 rows x 4 columns]

# %% [markdown]
# # DESAFIO 3
# Colocar o número de avaliações por filme, isto é, não só a média TOTAL de votos por filme

# %%
total_avaliacoes_usuario_filme = avaliacoes
total_avaliacoes_usuario_filme = total_avaliacoes_usuario_filme.rename(columns={"usuarioId" : "totalUsuario"})
total_avaliacoes_usuario_filme = total_avaliacoes_usuario_filme.groupby(by="filmeId")
total_avaliacoes_usuario_filme = total_avaliacoes_usuario_filme["totalUsuario"].count()
#total_avaliacoes_usuario_filme.head(5)

total_avaliacoes_por_filme = avaliacoes.join(total_avaliacoes_usuario_filme, on="filmeId")
total_avaliacoes_por_filme.head()
# Out:
#    usuarioId  filmeId  nota    momento  totalUsuario
# 0          1        1   4.0  964982703           215
# 1          1        3   4.0  964981247            52
# 2          1        6   4.0  964982224           102
# 3          1       47   5.0  964983815           203
# 4          1       50   5.0  964982931           204

# %%
avaliacoes.query("filmeId in [1,2,102084]")
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 560            6        2   4.0   845553522
# 874            7        1   4.5  1106635946
# 1026           8        2   4.0   839463806
# ...          ...      ...   ...         ...
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 98667        608        2   2.0  1117490786
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [326 rows x 4 columns]

# %%
avaliacoes.query('filmeId==1').plot()

# %%
avaliacoes.query("filmeId==1")["nota"].plot()

# %%
#tipo de gráfico histograma
avaliacoes.query("filmeId==1")["nota"].plot(kind='hist')

# %%
avaliacoes.query("filmeId==102084")["nota"].plot(kind='hist')

# %%
import matplotlib.pyplot as plt
avaliacoes.query("filmeId==1")["nota"].plot(kind='hist', title="Avaliações do filme Toy Story")
#avaliacoes.query("filmeId==1")["nota"].plot(kind='hist')
#plt.title("Avaliações do filme Toy Story")
plt.show()

# %% [markdown]
# ## DESAFIO 4
# Arrendondar as médias(coluna de nota média) para duas casas decimais.

# %%
notas_arrendondadas = filmes_com_media
notas_arrendondadas["nota"] = notas_arrendondadas["nota"].round(2)
notas_arrendondadas.head()
# Out:
#    filmeId  ...  nota
# 0        1  ...  3.92
# 1        2  ...  3.43
# 2        3  ...  3.26
# 3        4  ...  2.36
# 4        5  ...  3.07
#
# [5 rows x 4 columns]

# %% [markdown]
# ## DESAFIO 5
# Descobrir os gêneros dos filmes(quais são eles  únicos)

# %%
generos_sem_pipe = filmes_com_media
gen = generos_sem_pipe.generos.str.split('|')
list_exploded = gen.explode()
#listExploded.groupby()
list_generos = pd.DataFrame(list_exploded)
#list_generos.count()
list_generos_agrupada = list_generos.groupby("generos")
#20 com group by / sem o group by 22084
#len(list_generos_agrupada)
list_generos_agrupada_final = pd.DataFrame(list_generos_agrupada)
list_generos_agrupada_final[0]
# Out:
# 0     (no genres listed)
# 1                 Action
# 2              Adventure
# 3              Animation
# 4               Children
# 5                 Comedy
# 6                  Crime
# 7            Documentary
# 8                  Drama
# 9                Fantasy
# 10             Film-Noir
# 11                Horror
# 12                  IMAX
# 13               Musical
# 14               Mystery
# 15               Romance
# 16                Sci-Fi
# 17              Thriller
# 18                   War
# 19               Western
# Name: 0, dtype: object

# %% [markdown]
# ##DESAFIO 6
# Contar o número de aparições de cada gênero.

# %%
generos_dataframe = pd.DataFrame(list_exploded)
generos_contados_por_genero = generos_dataframe.groupby(['generos']).size()
generos_contados_por_genero

#Action 1828 Adventure 1263 Animation 611 Children 664 IMAX 158
#contraprova_generos_count = pd.DataFrame(list_exploded)
#contraprova_generos_count.query("generos=='IMAX'").count()
# Out:
# generos
# (no genres listed)      34
# Action                1828
# Adventure             1263
# Animation              611
# Children               664
# Comedy                3756
# Crime                 1199
# Documentary            440
# Drama                 4361
# Fantasy                779
# Film-Noir               87
# Horror                 978
# IMAX                   158
# Musical                334
# Mystery                573
# Romance               1596
# Sci-Fi                 980
# Thriller              1894
# War                    382
# Western                167
# dtype: int64

# %% [markdown]
# ## DESAFIO 7
# Plotar o gráfico de aparições de cada gênero. Pode ser um gráfico de tipo igual a barra

# %%
genero_serie = generos_contados_por_genero
genero_serie.plot(kind='bar', figsize=(16, 6))

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#para trocar as cores da paleta é possível configura através para propriedade pallete
#quando por exemplo uma palette BuGn_r, ela por padrão tem 6 elemento e repete caso tenha mais, para isso não ocorrer
#pode ser configurada através da propriedade n_colors
#quando o primeiro elemento ficar branco de mais pode ser feito a gambi e somado um número aletório ao len para chegar ao tom

#set style é global
sns.set_style("whitegrid")

gerar_grafico_por_genero = filmes_com_media
gerar_grafico_por_genero = gerar_grafico_por_genero["generos"]
gerar_grafico_por_genero = gerar_grafico_por_genero.str.get_dummies("|").sum().sort_values(ascending = False)
plt.figure(figsize=(16,8))
sns.barplot(x=gerar_grafico_por_genero.index, 
            y=gerar_grafico_por_genero.values, 
            palette=sns.color_palette("BuGn_r", n_colors=len(gerar_grafico_por_genero + 4)))
plt.show()

# %% [markdown]
# # DESAFIO 1
# Rotacionar os thicks(nomes dos gêneros)

# %%
plt.figure(figsize=(16,8))
grafico_desafio_1 = sns.barplot(x=gerar_grafico_por_genero.index, 
            y=gerar_grafico_por_genero.values, 
            palette=sns.color_palette("BuGn_r", n_colors=len(gerar_grafico_por_genero + 4)))
grafico_desafio_1.set_xticklabels(grafico_desafio_1.get_xticklabels(), rotation=45)
plt.show()

# %%
filmes_com_media_novo = filmes_com_media
filmes_com_media_novo.sort_values("nota", ascending=False)[2450:2500]
# Out:
#       filmeId  ...      nota
# 745       973  ...  3.900000
# 6632    56251  ...  3.900000
# 101       116  ...  3.900000
# 5719    27846  ...  3.900000
# 802      1050  ...  3.900000
# 3983     5617  ...  3.900000
# 1323     1785  ...  3.900000
# 7103    70599  ...  3.900000
# 5248     8607  ...  3.900000
# 4677     6985  ...  3.900000
# 86         97  ...  3.900000
# 4100     5876  ...  3.900000
# 4298     6283  ...  3.900000
# 8533   114935  ...  3.900000
# 7946    95858  ...  3.900000
# 1630     2176  ...  3.900000
# 3016     4034  ...  3.900000
# 4702     7018  ...  3.900000
# 2156     2871  ...  3.900000
# 9710   187595  ...  3.900000
# 1051     1366  ...  3.900000
# 6613    55820  ...  3.898438
# 939      1240  ...  3.896947
# 267       307  ...  3.895833
# 599       745  ...  3.895833
# 706       924  ...  3.894495
# 2078     2762  ...  3.893855
# 1608     2150  ...  3.892857
# 5165     8366  ...  3.892857
# 1432     1955  ...  3.892857
# 2191     2912  ...  3.892857
# 5572    26776  ...  3.892857
# 198       232  ...  3.892857
# 9223   152081  ...  3.890625
# 5885    33166  ...  3.890000
# 3564     4880  ...  3.888889
# 4258     6214  ...  3.888889
# 6884    63072  ...  3.888889
# 7078    69844  ...  3.887931
# 785      1028  ...  3.887324
# 7413    80463  ...  3.885965
# 6151    44191  ...  3.885000
# 7688    89492  ...  3.884615
# 6223    45728  ...  3.884615
# 912      1211  ...  3.884615
# 6242    46578  ...  3.883117
# 1230     1635  ...  3.882353
# 225       261  ...  3.880952
# 701       919  ...  3.880435
# 968      1269  ...  3.879310
#
# [50 rows x 4 columns]

# %%
#definir uma função:
#uma função não retorna nada a não ser que seja colocado o return
def plot_filme(n):
    notas_do_filme = avaliacoes.query(f"filmeId=={n}")["nota"]
    notas_do_filme.plot(kind="hist")
    return notas_do_filme.describe()

plot_filme(919)
# Out:
# count    92.000000
# mean      3.880435
# std       1.025418
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %%
plot_filme(46578)
# Out:
# count    77.000000
# mean      3.883117
# std       0.842522
# min       1.000000
# 25%       3.500000
# 50%       4.000000
# 75%       4.500000
# max       5.000000
# Name: nota, dtype: float64

# %% [markdown]
# ## DESAFIO 2
# Comparar outros filmes com notas próximas e achar distribuições bem diferentes

# %%
def plot_filme_desafio(n, title):
    notas_do_filme = avaliacoes.query(f"filmeId=={n}")["nota"]
    notas_do_filme.plot(kind="hist" ,title=f"{title}")
    plt.show()
    notas_do_filme.plot.box()
    plt.show()
    return notas_do_filme.describe()

plot_filme_desafio(89492, "Moneyball (2011)")
plot_filme_desafio(1211, "Wings of Desire (Himmel über Berlin, Der) (1987)	")
plot_filme_desafio(44191, "V for Vendetta (2006)")
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# count    100.000000
# mean       3.885000
# std        0.787705
# min        0.500000
# 25%        3.500000
# 50%        4.000000
# 75%        4.500000
# max        5.000000
# Name: nota, dtype: float64

# %%
def plot_filme(n):
    notas_do_filme = avaliacoes.query(f"filmeId=={n}")["nota"]
    notas_do_filme.plot(kind="hist")
    plt.show()
    notas_do_filme.plot.box()
    plt.show()
    return notas_do_filme.describe()

plot_filme(919)
# Out:
# count    92.000000
# mean      3.880435
# std       1.025418
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# Name: nota, dtype: float64

# %% [markdown]
# ## DESAFIO 3
# Criar o boxplot dos 10 filmes com mais votos (não é com maior média, é com mais votos!)

# %%
#top_10_mais_votados = total_avaliacoes_por_filme.sort_values(["nota", "totalUsuario"], ascending=False)
top_10_mais_votados = total_avaliacoes_por_filme.sort_values(["totalUsuario"], ascending=False)
#top_10_mais_votados = total_avaliacoes_por_filme.sort_values(["nota"], ascending=False)
top_10_mais_votados = top_10_mais_votados.head(10)
sns.boxplot(data=top_10_mais_votados, x="filmeId", y="nota")

# %%
sns.boxplot(data=avaliacoes.query("filmeId in [1, 2, 919, 46578]"), x="filmeId", y="nota")

# %% [markdown]
# ##DESAFIO 4
# O boxplot estar com um tamanho adequado e com os nomes dos filmes no thicks(legendas)

# %%
amostra_desafio_4 = filmes_com_media.head(15)

plt.figure(figsize=(16,8))
grafico_desafio_4 = sns.boxplot(data=amostra_desafio_4, x="titulo", y="nota")
grafico_desafio_4.set_xticklabels(grafico_desafio_4.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Toy Story (1995)'),
#  Text(0, 0, 'Jumanji (1995)'),
#  Text(0, 0, 'Grumpier Old Men (1995)'),
#  Text(0, 0, 'Waiting to Exhale (1995)'),
#  Text(0, 0, 'Father of the Bride Part II (1995)'),
#  Text(0, 0, 'Heat (1995)'),
#  Text(0, 0, 'Sabrina (1995)'),
#  Text(0, 0, 'Tom and Huck (1995)'),
#  Text(0, 0, 'Sudden Death (1995)'),
#  Text(0, 0, 'GoldenEye (1995)'),
#  Text(0, 0, 'American President, The (1995)'),
#  Text(0, 0, 'Dracula: Dead and Loving It (1995)'),
#  Text(0, 0, 'Balto (1995)'),
#  Text(0, 0, 'Nixon (1995)'),
#  Text(0, 0, 'Cutthroat Island (1995)')]

# %% [markdown]
# ##DESAFIO 5
# Calcular a moda, média, mediana dos filmes. Explore filmes com nota mais próxima  de 0.5, 3 e 5.

# %%
desafio_5 = filmes_com_media.query("nota in [0.5, 3, 5]")
#desafio_5.describe()

media_desafio_5 = desafio_5["nota"].mean()
mediana_desafio_5 = desafio_5["nota"].median()
moda_desafio_5 = desafio_5["nota"].mode()

dataframe_desafio_5 = pd.DataFrame(desafio_5["nota"])
dataframe_desafio_5 = dataframe_desafio_5.rename(columns={"nota": "total_notas"})
dataframe_desafio_5["total_notas"] = dataframe_desafio_5["total_notas"].count()
dataframe_desafio_5 = dataframe_desafio_5.groupby("total_notas")

#dataframe_desafio_5["media"] = media_desafio_5
#dataframe_desafio_5["mediana"] = mediana_desafio_5
#dataframe_desafio_5["moda"] = moda_desafio_5

print("Media")
print(media_desafio_5)
print("Mediana")
print(mediana_desafio_5)
print("Moda")
print(moda_desafio_5)

#dataframe_desafio_5
# Out:
# Media
# 3.26890756302521
# Mediana
# 3.0
# Moda
# 0    3.0
# dtype: float64

# %% [markdown]
# ##DESAFIO 6
# Plotar o boxplot e o histograma um ao lado do outro(na mesma figura ou em figuras distintas)

# %%
amostra_desafio_6 = filmes_com_media.head(15)

fig = plt.figure(figsize=(16, 8))

# Divide the figure into a 1x2 grid, and give me the first section
ax1 = fig.add_subplot(121)

# Divide the figure into a 1x2 grid, and give me the second section
ax2 = fig.add_subplot(122)

grafico_desafio_6 = sns.boxplot(data=amostra_desafio_6, x="titulo", y="nota", ax=ax1)
grafico_desafio_6.set_xticklabels(grafico_desafio_6.get_xticklabels(), rotation=45)

grafico_hist = amostra_desafio_6["nota"]
grafico_hist.plot(kind="hist", ax=ax2)

# %% [markdown]
# ##DESAFIO 7
# Gráfico de notas médias por ano

# %%
desafio_7 = avaliacoes

desafio_7_momento = pd.to_datetime(desafio_7["momento"], unit='s')
desafio_7 = desafio_7.sort_values("momento")
desafio_7["momento"] = desafio_7_momento.dt.strftime('%d/%m/%Y')

amostra_desafio_7 = desafio_7.groupby(by=["momento"])["nota"].mean()

dataframe_desafio_7 = pd.DataFrame(amostra_desafio_7[555:560])
fig = plt.figure(figsize=(16, 8))

grafico_hist = dataframe_desafio_7["nota"]
grafico_hist.plot()

# %% [markdown]
# ##AULA 3

# %%
imdb = pd.read_csv("https://gist.githubusercontent.com/guilhermesilveira/24e271e68afe8fd257911217b88b2e07/raw/e70287fb1dcaad4215c3f3c9deda644058a616bc/movie_metadata.csv")
imdb.head()
# Out:
#    color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0  Color      James Cameron  ...          1.78                 33000
# 1  Color     Gore Verbinski  ...          2.35                     0
# 2  Color         Sam Mendes  ...          2.35                 85000
# 3  Color  Christopher Nolan  ...          2.35                164000
# 4    NaN        Doug Walker  ...           NaN                     0
#
# [5 rows x 28 columns]

# %%
imdb["color"].unique()
# Out:
# array(['Color', nan, ' Black and White'], dtype=object)

# %%
imdb["color"].value_counts()
# Out:
# Color               4815
#  Black and White     209
# Name: color, dtype: int64

# %%
imdb["color"].value_counts(normalize=True)
# Out:
# Color               0.9584
#  Black and White    0.0416
# Name: color, dtype: float64

# %%
imdb["director_name"].value_counts()
# Out:
# Steven Spielberg      26
# Woody Allen           22
# Clint Eastwood        20
# Martin Scorsese       20
# Ridley Scott          17
#                       ..
# Steven E. de Souza     1
# Jerry Dugan            1
# Vicky Jenson           1
# Peter Ramsey           1
# Stewart Hendler        1
# Name: director_name, Length: 2398, dtype: int64

# %%
sns.distplot(imdb["gross"])

# %%
imdb.sort_values("gross", ascending=False).head()
# Out:
#      color    director_name  ...  aspect_ratio  movie_facebook_likes
# 0    Color    James Cameron  ...          1.78                 33000
# 26   Color    James Cameron  ...          2.35                 26000
# 29   Color  Colin Trevorrow  ...          2.00                150000
# 794  Color      Joss Whedon  ...          1.85                123000
# 17   Color      Joss Whedon  ...          1.85                123000
#
# [5 rows x 28 columns]

# %%
imdb.sort_values("gross", ascending=False).sample()
# Out:
#       color    director_name  ...  aspect_ratio  movie_facebook_likes
# 4835  Color  Jean-Luc Godard  ...          2.35                  2000
#
# [1 rows x 28 columns]

# %%
imdb.sort_values("gross", ascending=False).sample(10)
# Out:
#       color       director_name  ...  aspect_ratio  movie_facebook_likes
# 1232  Color  Jaume Collet-Serra  ...          2.35                 29000
# 727   Color   Peter Billingsley  ...          1.85                     0
# 2292  Color            Frank Oz  ...          1.85                     0
# 415   Color          Peter Berg  ...          2.35                     0
# 3086  Color    Christopher Cain  ...          1.85                   411
# 4012  Color    Warren P. Sonoda  ...          1.85                     0
# 3503  Color     Gurinder Chadha  ...          2.35                     0
# 1849  Color          Paul Weitz  ...          1.85                   736
# 1694  Color      Gavin O'Connor  ...          1.85                     0
# 154   Color  Alessandro Carloni  ...          2.35                 24000
#
# [10 rows x 28 columns]

# %% [markdown]
# ## Perguntas Gerais
# - Aventura tem nota melhor que comédia?
# - Diretor com mais filmes tem nota melhor? Tem mais faturamento?
# - As respostas são específicas para a amostra ou para o mundo?
# - Quais correlações existem entre os dados?
# - budget x gross (orçamento x faturamento)?
# - title_year com algo?

# %%
color_or_bw = imdb.query("color in ['Color', ' Black and White']")
len(color_or_bw)
# Out:
# 5024

# %%
color_or_bw["color_0_or_1"] = (color_or_bw["color"]=="Color") * 1
color_or_bw.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    color      director_name  ...  movie_facebook_likes  color_0_or_1
# 0  Color      James Cameron  ...                 33000             1
# 1  Color     Gore Verbinski  ...                     0             1
# 2  Color         Sam Mendes  ...                 85000             1
# 3  Color  Christopher Nolan  ...                164000             1
# 5  Color     Andrew Stanton  ...                 24000             1
#
# [5 rows x 29 columns]

# %%
sns.scatterplot(data=color_or_bw, x="color_0_or_1", y="gross")

# %%
color_or_bw.groupby("color").mean()["gross"]
# Out:
# color
#  Black and White    3.245702e+07
# Color               4.902619e+07
# Name: gross, dtype: float64

# %%
dev_bloxplot_1 = pd.DataFrame(color_or_bw.groupby("color").mean()["gross"]) 
dev_bloxplot_1 = dev_bloxplot_1.reset_index()
sns.boxplot(data=dev_bloxplot_1["gross"])

# %%
new_imdb = imdb
new_imdb.drop_duplicates()
new_imdb_usa = new_imdb.query("country== 'USA'")
budget_gross = new_imdb_usa[["budget", "gross"]].dropna().query("budget > 0 | gross > 0")
sns.scatterplot(x="budget", y="gross", data = budget_gross)

# %% [markdown]
# # lucro / prejuizo

# %%
new_imdb_usa['lucro'] = new_imdb_usa['gross'] - new_imdb_usa['budget']
budget_gross = new_imdb_usa.query("budget > 0 | gross > 0")[["budget", "lucro"]].dropna()
sns.scatterplot(x="budget", y="lucro", data = budget_gross)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## DESAFIO 1 - QUEM GASTOS OS TUBOS E TEVE ESSE PREJUIZÃO AI PRÓXIMO AO 2.5 E -2?

# %%
new_imdb_usa['lucro'] = new_imdb_usa['gross'] - new_imdb_usa['budget']
dev_1 = new_imdb_usa.query("budget > 0 | gross > 0")[["budget", "lucro", "movie_title"]].dropna()
dev_1.query("lucro < -100000000 ").sort_values("budget", ascending=False).head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            budget           lucro                           movie_title
# 5  263,700,000.00 -190,641,321.00                          John Carter
# 14 215,000,000.00 -125,710,090.00                      The Lone Ranger
# 28 209,000,000.00 -143,826,840.00                           Battleship
# 51 200,000,000.00 -109,244,357.00  Prince of Persia: The Sands of Time
# 49 195,000,000.00 -129,828,140.00                Jack the Giant Slayer

# %% [markdown]
# ##  DESAFIO 2 - FILMES MAIS RECENTES TIVERAM A MAIOR PREJUÍZO?

# %%
budget_gross = new_imdb_usa.query("budget > 0 | gross > 0")[["title_year", "lucro"]].dropna()
sns.scatterplot(x="title_year", y="lucro", data = budget_gross)

# %% [markdown]
# ## DESAFIO - Quem são os filmes pré 2a guerra que ganharão tanto?

# %%
dev_2 = new_imdb_usa.query("budget > 0 | gross > 0")[["title_year", "lucro", "movie_title"]].dropna()
dev_2.query("title_year < 1960 & lucro > 100000000").sort_values("lucro", ascending=False).head()
# Out:
#       title_year        lucro                       movie_title
# 3970      1939.0  194678278.0               Gone with the Wind
# 4449      1937.0  182925485.0  Snow White and the Seven Dwarfs

# %%
filmes_por_diretor = new_imdb_usa['director_name'].value_counts()
filmes_por_diretor.head()
# Out:
# Steven Spielberg    24
# Martin Scorsese     20
# Clint Eastwood      20
# Woody Allen         18
# Tim Burton          16
# Name: director_name, dtype: int64

# %%
gross_director = new_imdb_usa[["director_name","gross"]].set_index("director_name").join(filmes_por_diretor, on="director_name")
#gross_director.head()
gross_director.columns=["dindin", "filmes_irmaos"]
#gross_director.head()
gross_director = gross_director.reset_index()
gross_director.head()
# Out:
#        director_name       dindin  filmes_irmaos
# 0      James Cameron  760505847.0            6.0
# 1     Gore Verbinski  309404152.0            7.0
# 2  Christopher Nolan  448130642.0            8.0
# 3     Andrew Stanton   73058679.0            3.0
# 4          Sam Raimi  336530303.0           11.0

# %%
sns.scatterplot(x="filmes_irmaos", y="dindin", data=gross_director)

# %% [markdown]
# ## Desafio - Confirmar a tese genial do Paulo que o cidadão estranho é o Woody Allen.

# %%
gross_director.query("filmes_irmaos == 18").head(18)
# Out:
#      director_name      dindin  filmes_irmaos
# 1549   Woody Allen   7496522.0           18.0
# 1748   Woody Allen  16684352.0           18.0
# 1873   Woody Allen  13383737.0           18.0
# 1881   Woody Allen  10569071.0           18.0
# 1884   Woody Allen   9714482.0           18.0
# 1973   Woody Allen  33404871.0           18.0
# 1988   Woody Allen  17071230.0           18.0
# 2006   Woody Allen   3203044.0           18.0
# 2085   Woody Allen  14792779.0           18.0
# 2094   Woody Allen   4839383.0           18.0
# 2183   Woody Allen  10763469.0           18.0
# 2200   Woody Allen   5306447.0           18.0
# 2205   Woody Allen   3247816.0           18.0
# 2381   Woody Allen   5032496.0           18.0
# 2955   Woody Allen  39200000.0           18.0
# 3216   Woody Allen         NaN           18.0
# 3218   Woody Allen         NaN           18.0
# 3260   Woody Allen         NaN           18.0

# %% [markdown]
# ## Desafio - Interpretar melhor o gráfico e outros gráficos. Mudar marcadores.

# %%
sns.pairplot(data = new_imdb_usa[["gross", "budget", "lucro", "title_year"]])

# %%
#Correlação varia entre 1 e -1 sendo 1 mais cresce e -1 menos cresce
#Entre correlação 1 e -1 é que quando 1 cresce o outro baixa.
new_imdb_usa[["gross", "budget", "lucro", "title_year"]].corr()
# Out:
#                gross    budget     lucro  title_year
# gross       1.000000  0.646158  0.799260    0.036865
# budget      0.646158  1.000000  0.057774    0.232640
# lucro       0.799260  0.057774  1.000000   -0.122092
# title_year  0.036865  0.232640 -0.122092    1.000000

# %% [markdown]
# ## Desafio - calcular a correlação somente para o filme depois de 2000(jogar fora os de antes de 2000).
# ##Interpretar essa correlação - escrever.

# %%
dev_4 = new_imdb_usa[["gross", "budget", "lucro", "title_year"]]
#dev_4.query("title_year >= 2000").head()
dev_4.query("title_year >= 2000").corr()
#quanto maior o faturamento mais correlação tem com o orçamento maior o orçamento
#quanto maior o faturamento mais correlação tem com o lucro maior o lucro
#o ano nao tem correlação com nenhuma das variaveis
#quanto mairo o orçamento menos correlação com o lucro, menor o lucro
# Out:
#                gross    budget     lucro  title_year
# gross       1.000000  0.708050  0.774906    0.108058
# budget      0.708050  1.000000  0.102324    0.065052
# lucro       0.774906  0.102324  1.000000    0.034094
# title_year  0.108058  0.065052  0.034094    1.000000

# %% [markdown]
# ## Desafio - tentar encontrar uma reta, pode ser com uma régua no monitor (não faça isso), com excel/google sheets, com o phyton, no gráfico que parece se aproximar uma reta(por exemplo budget/lucro, budget/gross). Sendo com a reta é possível criar uma previsão.

# %% [markdown]
# ## Desafio - utilizar também as notas nas correlação, nos gráficos. Números de avaliações por ano pode ser também uma feature. (Imdb_score)
#
# ---

# %%
dev_6 = new_imdb_usa[["gross", "budget", "lucro", "title_year", "imdb_score"]]
#dev_6.query("title_year >= 2000").head()
dev_6.query("title_year >= 2000").corr()
# Out:
#                gross    budget     lucro  title_year  imdb_score
# gross       1.000000  0.708050  0.774906    0.108058    0.249787
# budget      0.708050  1.000000  0.102324    0.065052    0.175331
# lucro       0.774906  0.102324  1.000000    0.034094    0.244602
# title_year  0.108058  0.065052  0.034094    1.000000   -0.012965
# imdb_score  0.249787  0.175331  0.244602   -0.012965    1.000000

# %% [markdown]
# ##AULA 4

# %%
uri = "https://github.com/guilhermesilveira/enem-2018/blob/master/MICRODADOS_ENEM_2018_SAMPLE_43278.csv?raw=true"

# %%
dados = pd.read_csv(uri)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q025  Q026 Q027
# 0  180009327796    2018                  2112209  ...    B     A    A
# 1  180012890374    2018                  3557105  ...    B     D    D
# 2  180008223824    2018                  2506301  ...    B     A    E
# 3  180007859645    2018                  3534807  ...    A     B    A
# 4  180013499517    2018                  3523107  ...    B     A    A
#
# [5 rows x 137 columns]

# %%
# %precision %.2f
pd.options.display.float_format = '{:,.2f}'.format

dados.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        ...
#        'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024', 'Q025', 'Q026',
#        'Q027'],
#       dtype='object', length=137)

# %%
dados.describe()
# Out:
#             NU_INSCRICAO     NU_ANO  ...  NU_NOTA_REDACAO       Q005
# count         137,844.00 137,844.00  ...       103,774.00 137,844.00
# mean  180,010,423,553.31   2,018.00  ...           509.13       3.90
# std         1,918,950.00       0.00  ...           187.01       1.51
# min   180,007,186,686.00   2,018.00  ...             0.00       1.00
# 25%   180,008,761,760.75   2,018.00  ...           360.00       3.00
# 50%   180,010,373,993.50   2,018.00  ...           520.00       4.00
# 75%   180,012,032,768.50   2,018.00  ...           620.00       5.00
# max   180,014,002,596.00   2,018.00  ...         1,000.00      20.00
#
# [8 rows x 94 columns]

# %%
colunas_de_notas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']
dados_notas = dados[colunas_de_notas].dropna()
dados_notas.head()
# Out:
#    NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO
# 1      523.10      671.30      661.60      738.00           680.00
# 2      409.20      531.70      389.00      438.10           600.00
# 3      452.30      505.50      448.50      544.90           400.00
# 6      428.50      505.20      521.00      436.80           560.00
# 8      491.80      575.70      524.40      487.60           660.00

# %% [markdown]
# ## Desafio 1
# Se a pessoa não teve presença, preencher a nota da pessoa com algum número. A nota 0? A nota média? A mediana

# %%
dev_1_replace = dados[['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']]
dev_1_replace.columns = ['ciencias_naturais', 'ciencias_humanas', 'linguagem_codigo', 'matematica', 'redacao']
dev_1_replace = dev_1_replace.fillna(0)

res_dev_1 = pd.DataFrame()
res_dev_1["media"] = dev_1_replace[['ciencias_naturais', 'ciencias_humanas', 'linguagem_codigo', 'matematica', 'redacao']].mean()
res_dev_1["mediana"] = dev_1_replace[['ciencias_naturais', 'ciencias_humanas', 'linguagem_codigo', 'matematica', 'redacao']].median()
res_dev_1
#dev_1_replace.describe()
# Out:
#                    media  mediana
# ciencias_naturais 349.29   443.70
# ciencias_humanas  427.84   538.30
# linguagem_codigo  396.44   496.40
# matematica        378.69   466.10
# redacao           383.29   400.00

# %%
dados_notas.columns = ['ciencias_naturais', 'ciencias_humanas', 'linguagem_codigo', 'matematica', 'redacao']
corr = dados_notas.corr()
corr
# Out:
#                    ciencias_naturais  ciencias_humanas  ...  matematica  redacao
# ciencias_naturais               1.00              0.57  ...        0.58     0.51
# ciencias_humanas                0.57              1.00  ...        0.53     0.50
# linguagem_codigo                0.60              0.70  ...        0.57     0.56
# matematica                      0.58              0.53  ...        1.00     0.48
# redacao                         0.51              0.50  ...        0.48     1.00
#
# [5 rows x 5 columns]

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))


# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.heatmap(corr)

# %%
sns.pairplot(dados_notas, kind="reg")

# %% [markdown]
# ## Desafio 2
# A matriz de correlação está feiosa, deixa mais bonita :) e manter os valores lá dentro delas.

# %%
mask = np.triu(np.ones_like(corr, dtype=np.bool))
sns.heatmap(corr, mask = mask)

# %%
sns.pairplot(dados_notas)

# %% [markdown]
# ## Desafio 3
# Pairplot dos acertos de cada categoria (CN, CH, MT, LC, nota pura redação ) - Usar o gabarito e as respostas

# %%
#colunas_de_gabarito= ['TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC', 'TX_GABARITO_MT']
colunas_dev_3 = ['TX_RESPOSTAS_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_CH', 'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC', 'TX_GABARITO_MT','NU_NOTA_REDACAO']
dev_3 = dados[colunas_dev_3]
dev_3.head()
#dados.head()
# Out:
#                                  TX_RESPOSTAS_MT  ... NU_NOTA_REDACAO
# 0                                            NaN  ...             nan
# 1  ADDEDEEBCAADDEDEBECCBAECECEDBAADEABAECDADECDC  ...          680.00
# 2  ABCBEECAABDDADCACAAAABDDEDACAEEECCDCEBBABBECB  ...          600.00
# 3  DEBEBEABDABECACDDDECBBDDBCBBCABDAACCECBABDCDA  ...          400.00
# 4                                            NaN  ...             nan
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Desafio 4
# Remover todos os zeros. Tomar o cuidado que no desafio 1 já tomamos decisões ligadas a limpeza dos dados também. Você também pode exportar para outro CSV se quiser.

# %%
##replace 0 por null e drop na

# %% [markdown]
# ## Desafio 5
# Quais questões tiveram mais erros (análise sobre o gabarito x acertos x erros)

# %% [markdown]
# ## Desafio 6
# Estudar o que as pessoas que estudam o assunto estão discutindo e conclusões que já chegaram sobre a utilização de informações (principalmente sensíveis) para a machine learning e data science. Podcast do datahackers também sobre o assunto.
